# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
print(df["android_timestamp_LUX"].min(), df["android_timestamp_LUX"].max())
print(df_ppg["android_timestamp_PPG"].min(), df_ppg["android_timestamp_PPG"].max())
# Out:
# 1784372811123000000 1784374884063000000
# 1784372810724000000 1784373003913000000

# %%
df_ppg = pd.read_csv("/Users/tpfeffer/Downloads/ble_data_2026-07-28_16-21-37_ppg.csv")

val_bat = df_ppg["resp"].values
val_ppg = df_ppg["ppg"].values
ts_bat = df_ppg["android_timestamp_PPG"].values

df = pd.read_csv("/Users/tpfeffer/Downloads/ble_data_2026-07-28_16-21-02_lux.csv")

ts = df["android_timestamp_LUX"].values
val = df["lux"].values

f = plt.figure(figsize=(12, 3))

plt.plot(ts, val)
plt.plot(ts_bat, val_bat)

# %%
f = plt.figure(figsize=(12, 3))

# zscore val_ppg
# val_ppg = (val_ppg - np.mean(val_ppg)) / np.std(val_ppg)
# val_bat = (val_bat - np.mean(val_bat)) / np.std(val_bat)

# plt.plot(ts_bat, val_ppg, label="PPG")
plt.plot(ts_bat, val_bat, label="Battery")

plt.legend()
# plt.xlim(ts_bat[0], ts_bat[1000])

# %%
f = plt.figure(figsize=(15, 3))
plt.plot(df_ppg["ppg"])

plt.xlim(40000, 42000)

plt.ylim(80000, 82000)
# Out:
# (80000.0, 82000.0)

# %%
(df_ppg["packet_arrival_android_timestamp_PPG"].values[-1] - df_ppg["android_timestamp_PPG"].values[0]) / 1e9
# Out:
# np.float64(10.492)

# %%
x = np.diff(df_ppg["packet_arrival_android_timestamp_PPG"])
# remove zeros
x = x[x != 0]

plt.plot(x)

# %%
f = plt.figure(figsize=(12, 3))

plt.plot(val_bat/1000)
plt.ylabel("Voltage (V)")

# plt.xlim(156050, 157800)

# plot power spectrum using np.fft.fft and np.fft.fftfreq
f = plt.figure(figsize=(12, 3))

fs = np.fft.fftfreq(len(val_bat), d=1/1000)
ps = np.abs(np.fft.fft(val_bat))**2

plt.plot(fs, ps)

plt.xlim(0, 200)
# Out:
# (0.0, 200.0)

# %%
np.diff(df["timestamp_LUX"])
# Out:
# array([101, 100, 101, 101, 101, 100, 101, 101, 100, 101, 101, 101, 100,
#        101, 101, 101, 100, 101, 101, 101, 100, 101, 101, 100, 101, 101,
#        101, 100, 101, 101, 101, 100, 101, 100, 101, 101, 101, 101, 100,
#        101, 101, 101, 100, 101, 101, 101, 100, 101, 100, 101, 101, 101,
#        100, 101, 101, 101, 100, 101, 101, 101, 101, 100, 101, 101, 101,
#        100, 101, 101, 100, 101, 101, 101, 100, 101, 101, 100, 101, 101,
#        100, 101, 101, 101, 101, 100, 101, 101, 100, 101, 101, 101, 100,
#        101, 101, 100, 101, 101, 101, 100, 101, 101, 101, 100, 101, 101,
#        101, 101, 100, 101, 101, 101, 100, 101, 101, 100, 101, 101, 101,
#        100, 101, 101, 100, 101, 101, 100, 102, 100, 101, 101, 100])

# %%
f = plt.figure(figsize=(12, 3)  )
plt.plot(ts_bat, val_bat)

f = plt.figure(figsize=(12, 3)  )
plt.plot(ts, val)

# %%
df
# Out:
#      timestamp_LUX  android_timestamp_LUX  \
# 0            44017    1784457127856000000
# 1            44118    1784457127957000000
# 2            44219    1784457128058000000
# 3            44319    1784457128158000000
# 4            44420    1784457128259000000
# ..             ...                    ...
# 110          55098    1784457138937000000
# 111          55198    1784457139037000000
# 112          55299    1784457139138000000
# 113          55400    1784457139239000000
# 114          55500    1784457139339000000
#
#      packet_arrival_android_timestamp_LUX     lux     ir lux_gain  rtt_ms
# 0                     1784457128259000000  14.362  29212     Auto   27.43
# 1                     1784457128259000000  14.240  29212     Auto   27.43
# 2                     1784457128259000000  14.240  29212     Auto   27.43
# 3                     1784457128259000000  14.240  29212     Auto   27.43
# 4                     1784457128259000000  14.240  29212     Auto   27.43
# ..                                    ...     ...    ...      ...     ...
# 110                   1784457139347000000  14.077  28886     Auto   28.82
# 111                   1784457139347000000  13.955  28886     Auto   28.82
# 112                   1784457139347000000  13.955  28886     Auto   28.82
# 113                   1784457139347000000  14.117  28723     Auto   28.82
# 114                   1784457139347000000  14.117  28723     Auto   28.82
#
# [115 rows x 7 columns]
